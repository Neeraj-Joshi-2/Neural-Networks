# %% [markdown]
# # Neeraj Joshi
# # Experiment - Implementation of  Generative adversarial networks

# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
from torch.utils.data import DataLoader

if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %%
# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Hyperparameters
random_seed = 123
generator_learning_rate = 0.001
discriminator_learning_rate = 0.001
num_epochs = 100
batch_size = 128
LATENT_DIM = 100
IMG_SHAPE = (1, 28, 28)
IMG_SIZE = 1
for x in IMG_SHAPE:
    IMG_SIZE *= x

# %%
train_dataset = datasets.MNIST(root='data',train=True,transform=transforms.ToTensor(),download=True)

test_dataset = datasets.MNIST(root='data',train=False,transform=transforms.ToTensor())

train_loader = DataLoader(dataset=train_dataset,batch_size=batch_size,shuffle=True)

test_loader = DataLoader(dataset=test_dataset,batch_size=batch_size,shuffle=False)

# %%
# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Image batch dimensions: torch.Size([128, 1, 28, 28])
# Image label dimensions: torch.Size([128])

# %%
class GAN(torch.nn.Module):

    def __init__(self):
        super(GAN, self).__init__()
        
        self.generator = nn.Sequential(
            nn.Linear(LATENT_DIM, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, IMG_SIZE),
            nn.Tanh())
        
        self.discriminator = nn.Sequential(
            nn.Linear(IMG_SIZE, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, 1),
            nn.Sigmoid())

    def generator_forward(self, z):
        img = self.generator(z)
        return img
    
    def discriminator_forward(self, img):
        pred = model.discriminator(img)
        return pred.view(-1)

# %%
torch.manual_seed(random_seed)

model = GAN()
model = model.to(device)

optim_gener = torch.optim.Adam(model.generator.parameters(), lr=generator_learning_rate)
optim_discr = torch.optim.Adam(model.discriminator.parameters(), lr=discriminator_learning_rate)

# %%
start_time = time.time()    

discr_costs = []
gener_costs = []
for epoch in range(num_epochs):
    model = model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):

        features = (features - 0.5)*2.
        features = features.view(-1, IMG_SIZE).to(device) 
        targets = targets.to(device)

        valid = torch.ones(targets.size(0)).float().to(device)
        fake = torch.zeros(targets.size(0)).float().to(device)
        
        # FORWARD AND BACK PROP
        # --------------------------
        # Train Generator
        # --------------------------
        
        # Make new images
        z = torch.zeros((targets.size(0), LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
        generated_features = model.generator_forward(z)
        
        # Loss for fooling the discriminator
        discr_pred = model.discriminator_forward(generated_features)
        gener_loss = F.binary_cross_entropy(discr_pred, valid)
        optim_gener.zero_grad()
        gener_loss.backward()
        optim_gener.step()
        
        # --------------------------
        # Train Discriminator
        # --------------------------        
        
        discr_pred_real = model.discriminator_forward(features.view(-1, IMG_SIZE))
        real_loss = F.binary_cross_entropy(discr_pred_real, valid)
        
        discr_pred_fake = model.discriminator_forward(generated_features.detach())
        fake_loss = F.binary_cross_entropy(discr_pred_fake, fake)
        
        discr_loss = 0.5*(real_loss + fake_loss)

        optim_discr.zero_grad()
        discr_loss.backward()
        optim_discr.step()        
        
        discr_costs.append(discr_loss.item())
        gener_costs.append(gener_loss.item())
          
        ### LOGGING
        if not batch_idx % 100:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Gen/Dis Loss: %.4f/%.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), gener_loss, discr_loss))

    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
    
print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/100 | Batch 000/469 | Gen/Dis Loss: 0.6817/0.7123
# Epoch: 001/100 | Batch 100/469 | Gen/Dis Loss: 4.6622/0.0372
# Epoch: 001/100 | Batch 200/469 | Gen/Dis Loss: 1.6639/0.1155
# Epoch: 001/100 | Batch 300/469 | Gen/Dis Loss: 1.8110/0.1363
# Epoch: 001/100 | Batch 400/469 | Gen/Dis Loss: 1.1353/0.3299
# Time elapsed: 0.17 min
# Epoch: 002/100 | Batch 000/469 | Gen/Dis Loss: 2.3664/0.1204
# Epoch: 002/100 | Batch 100/469 | Gen/Dis Loss: 1.0108/0.3953
# Epoch: 002/100 | Batch 200/469 | Gen/Dis Loss: 1.1143/0.4610
# Epoch: 002/100 | Batch 300/469 | Gen/Dis Loss: 1.0902/0.4384
# Epoch: 002/100 | Batch 400/469 | Gen/Dis Loss: 0.9469/0.4152
# Time elapsed: 0.33 min
# Epoch: 003/100 | Batch 000/469 | Gen/Dis Loss: 1.0992/0.4043
# Epoch: 003/100 | Batch 100/469 | Gen/Dis Loss: 1.6342/0.2988
# Epoch: 003/100 | Batch 200/469 | Gen/Dis Loss: 1.1986/0.4006
# Epoch: 003/100 | Batch 300/469 | Gen/Dis Loss: 1.5542/0.3217
# Epoch: 003/100 | Batch 400/469 | Gen/Dis Loss: 1.7662/0.2953
# Time elapsed: 0.50 min
# Epoch: 004/100 | Batch 000/469 | Gen/Dis Loss: 2.2948/0.2243
# Epoch: 004/100 | Batch 100/469 | Gen/Dis Loss: 1.1544/0.3288
# Epoch: 004/100 | Batch 200/469 | Gen/Dis Loss: 1.2034/0.3580
# Epoch: 004/100 | Batch 300/469 | Gen/Dis Loss: 1.3674/0.4892
# Epoch: 004/100 | Batch 400/469 | Gen/Dis Loss: 1.4339/0.4394
# Time elapsed: 0.67 min
# Epoch: 005/100 | Batch 000/469 | Gen/Dis Loss: 0.9949/0.4719
# Epoch: 005/100 | Batch 100/469 | Gen/Dis Loss: 0.7851/0.5112
# Epoch: 005/100 | Batch 200/469 | Gen/Dis Loss: 1.1969/0.5967
# Epoch: 005/100 | Batch 300/469 | Gen/Dis Loss: 1.1758/0.4708
# Epoch: 005/100 | Batch 400/469 | Gen/Dis Loss: 1.0521/0.4695
# Time elapsed: 0.84 min
# Epoch: 006/100 | Batch 000/469 | Gen/Dis Loss: 1.5340/0.4146
# Epoch: 006/100 | Batch 100/469 | Gen/Dis Loss: 1.2307/0.4735
# Epoch: 006/100 | Batch 200/469 | Gen/Dis Loss: 0.9150/0.5267
# Epoch: 006/100 | Batch 300/469 | Gen/Dis Loss: 1.1287/0.4791
# Epoch: 006/100 | Batch 400/469 | Gen/Dis Loss: 1.0785/0.4967
# Time elapsed: 1.01 min
# Epoch: 007/100 | Batch 000/469 | Gen/Dis Loss: 1.5692/0.5029
# Epoch: 007/100 | Batch 100/469 | Gen/Dis Loss: 0.9454/0.5935
# Epoch: 007/100 | Batch 200/469 | Gen/Dis Loss: 1.5000/0.5805
# Epoch: 007/100 | Batch 300/469 | Gen/Dis Loss: 0.9119/0.5498
# Epoch: 007/100 | Batch 400/469 | Gen/Dis Loss: 0.9328/0.6138
# Time elapsed: 1.17 min
# Epoch: 008/100 | Batch 000/469 | Gen/Dis Loss: 1.1819/0.5340
# Epoch: 008/100 | Batch 100/469 | Gen/Dis Loss: 1.0406/0.5689
# Epoch: 008/100 | Batch 200/469 | Gen/Dis Loss: 0.9503/0.5175
# Epoch: 008/100 | Batch 300/469 | Gen/Dis Loss: 1.0964/0.5193
# Epoch: 008/100 | Batch 400/469 | Gen/Dis Loss: 1.6819/0.4371
# Time elapsed: 1.34 min
# Epoch: 009/100 | Batch 000/469 | Gen/Dis Loss: 0.8874/0.5111
# Epoch: 009/100 | Batch 100/469 | Gen/Dis Loss: 1.2955/0.3992
# Epoch: 009/100 | Batch 200/469 | Gen/Dis Loss: 1.1829/0.5065
# Epoch: 009/100 | Batch 300/469 | Gen/Dis Loss: 1.0704/0.5444
# Epoch: 009/100 | Batch 400/469 | Gen/Dis Loss: 1.1593/0.4749
# Time elapsed: 1.51 min
# Epoch: 010/100 | Batch 000/469 | Gen/Dis Loss: 1.0306/0.5125
# Epoch: 010/100 | Batch 100/469 | Gen/Dis Loss: 1.1856/0.4911
# Epoch: 010/100 | Batch 200/469 | Gen/Dis Loss: 1.1204/0.5332
# Epoch: 010/100 | Batch 300/469 | Gen/Dis Loss: 1.0856/0.5498
# Epoch: 010/100 | Batch 400/469 | Gen/Dis Loss: 1.2461/0.5249
# Time elapsed: 1.67 min
# Epoch: 011/100 | Batch 000/469 | Gen/Dis Loss: 1.2828/0.5122
# Epoch: 011/100 | Batch 100/469 | Gen/Dis Loss: 1.9396/0.3660
# Epoch: 011/100 | Batch 200/469 | Gen/Dis Loss: 1.6118/0.6111
# Epoch: 011/100 | Batch 300/469 | Gen/Dis Loss: 1.3070/0.4377
# Epoch: 011/100 | Batch 400/469 | Gen/Dis Loss: 1.4579/0.4815
# Time elapsed: 1.84 min
# Epoch: 012/100 | Batch 000/469 | Gen/Dis Loss: 1.7075/0.4412
# Epoch: 012/100 | Batch 100/469 | Gen/Dis Loss: 1.2692/0.5437
# Epoch: 012/100 | Batch 200/469 | Gen/Dis Loss: 1.4287/0.5764
# Epoch: 012/100 | Batch 300/469 | Gen/Dis Loss: 1.2620/0.5161
# Epoch: 012/100 | Batch 400/469 | Gen/Dis Loss: 1.3883/0.6204
# Time elapsed: 2.01 min
# Epoch: 013/100 | Batch 000/469 | Gen/Dis Loss: 1.2619/0.5048
# Epoch: 013/100 | Batch 100/469 | Gen/Dis Loss: 1.4000/0.4934
# Epoch: 013/100 | Batch 200/469 | Gen/Dis Loss: 0.9806/0.5607
# Epoch: 013/100 | Batch 300/469 | Gen/Dis Loss: 1.0419/0.6041
# Epoch: 013/100 | Batch 400/469 | Gen/Dis Loss: 1.1416/0.5337
# Time elapsed: 2.18 min
# Epoch: 014/100 | Batch 000/469 | Gen/Dis Loss: 1
# Epoch: 080/100 | Batch 400/469 | Gen/Dis Loss: 0.8665/0.6451
# Time elapsed: 13.23 min
# Epoch: 081/100 | Batch 000/469 | Gen/Dis Loss: 0.7879/0.6430
# Epoch: 081/100 | Batch 100/469 | Gen/Dis Loss: 0.7831/0.6786
# Epoch: 081/100 | Batch 200/469 | Gen/Dis Loss: 0.8194/0.6622
# Epoch: 081/100 | Batch 300/469 | Gen/Dis Loss: 0.8259/0.6408
# Epoch: 081/100 | Batch 400/469 | Gen/Dis Loss: 0.8583/0.6394
# Time elapsed: 13.39 min
# Epoch: 082/100 | Batch 000/469 | Gen/Dis Loss: 0.7812/0.6728
# Epoch: 082/100 | Batch 100/469 | Gen/Dis Loss: 1.0281/0.6324
# Epoch: 082/100 | Batch 200/469 | Gen/Dis Loss: 0.8686/0.6525
# Epoch: 082/100 | Batch 300/469 | Gen/Dis Loss: 0.7271/0.6435
# Epoch: 082/100 | Batch 400/469 | Gen/Dis Loss: 0.7472/0.6455
# Time elapsed: 13.55 min
# Epoch: 083/100 | Batch 000/469 | Gen/Dis Loss: 1.0958/0.6420
# Epoch: 083/100 | Batch 100/469 | Gen/Dis Loss: 0.8087/0.6293
# Epoch: 083/100 | Batch 200/469 | Gen/Dis Loss: 0.7781/0.6649
# Epoch: 083/100 | Batch 300/469 | Gen/Dis Loss: 1.1001/0.6409
# Epoch: 083/100 | Batch 400/469 | Gen/Dis Loss: 0.9405/0.6127
# Time elapsed: 13.72 min
# Epoch: 084/100 | Batch 000/469 | Gen/Dis Loss: 0.7934/0.6255
# Epoch: 084/100 | Batch 100/469 | Gen/Dis Loss: 0.8071/0.6327
# Epoch: 084/100 | Batch 200/469 | Gen/Dis Loss: 0.7741/0.6310
# Epoch: 084/100 | Batch 300/469 | Gen/Dis Loss: 0.8671/0.6224
# Epoch: 084/100 | Batch 400/469 | Gen/Dis Loss: 0.8435/0.6478
# Time elapsed: 13.88 min
# Epoch: 085/100 | Batch 000/469 | Gen/Dis Loss: 0.8229/0.6479
# Epoch: 085/100 | Batch 100/469 | Gen/Dis Loss: 0.8103/0.6232
# Epoch: 085/100 | Batch 200/469 | Gen/Dis Loss: 0.8194/0.6492
# Epoch: 085/100 | Batch 300/469 | Gen/Dis Loss: 0.9092/0.6563
# Epoch: 085/100 | Batch 400/469 | Gen/Dis Loss: 0.7178/0.6494
# Time elapsed: 14.05 min
# Epoch: 086/100 | Batch 000/469 | Gen/Dis Loss: 0.6935/0.6566
# Epoch: 086/100 | Batch 100/469 | Gen/Dis Loss: 0.7357/0.6757
# Epoch: 086/100 | Batch 200/469 | Gen/Dis Loss: 0.9150/0.6290
# Epoch: 086/100 | Batch 300/469 | Gen/Dis Loss: 0.8207/0.6191
# Epoch: 086/100 | Batch 400/469 | Gen/Dis Loss: 0.8197/0.6574
# Time elapsed: 14.21 min
# Epoch: 087/100 | Batch 000/469 | Gen/Dis Loss: 0.7891/0.6759
# Epoch: 087/100 | Batch 100/469 | Gen/Dis Loss: 0.8963/0.6330
# Epoch: 087/100 | Batch 200/469 | Gen/Dis Loss: 0.7182/0.6524
# Epoch: 087/100 | Batch 300/469 | Gen/Dis Loss: 0.7281/0.6652
# Epoch: 087/100 | Batch 400/469 | Gen/Dis Loss: 0.8678/0.6370
# Time elapsed: 14.38 min
# Epoch: 088/100 | Batch 000/469 | Gen/Dis Loss: 0.7904/0.6747
# Epoch: 088/100 | Batch 100/469 | Gen/Dis Loss: 0.7504/0.6276
# Epoch: 088/100 | Batch 200/469 | Gen/Dis Loss: 0.8272/0.6237
# Epoch: 088/100 | Batch 300/469 | Gen/Dis Loss: 0.8104/0.6481
# Epoch: 088/100 | Batch 400/469 | Gen/Dis Loss: 0.7603/0.6755
# Time elapsed: 14.54 min
# Epoch: 089/100 | Batch 000/469 | Gen/Dis Loss: 0.8434/0.6716
# Epoch: 089/100 | Batch 100/469 | Gen/Dis Loss: 0.7999/0.6523
# Epoch: 089/100 | Batch 200/469 | Gen/Dis Loss: 0.8226/0.6537
# Epoch: 089/100 | Batch 300/469 | Gen/Dis Loss: 0.7112/0.6709
# Epoch: 089/100 | Batch 400/469 | Gen/Dis Loss: 0.7827/0.6385
# Time elapsed: 14.71 min
# Epoch: 090/100 | Batch 000/469 | Gen/Dis Loss: 0.7586/0.6600
# Epoch: 090/100 | Batch 100/469 | Gen/Dis Loss: 0.8509/0.6692
# Epoch: 090/100 | Batch 200/469 | Gen/Dis Loss: 0.7887/0.6561
# Epoch: 090/100 | Batch 300/469 | Gen/Dis Loss: 0.8409/0.6458
# Epoch: 090/100 | Batch 400/469 | Gen/Dis Loss: 0.7966/0.6404
# Time elapsed: 14.88 min
# Epoch: 091/100 | Batch 000/469 | Gen/Dis Loss: 0.7914/0.6464
# Epoch: 091/100 | Batch 100/469 | Gen/Dis Loss: 0.8367/0.6727
# Epoch: 091/100 | Batch 200/469 | Gen/Dis Loss: 0.8101/0.6352
# Epoch: 091/100 | Batch 300/469 | Gen/Dis Loss: 0.7538/0.6360
# Epoch: 091/100 | Batch 400/469 | Gen/Dis Loss: 0.8405/0.6592
# Time elapsed: 15.05 min
# Epoch: 092/100 | Batch 000/469 | Gen/Dis Loss: 0.8141/0.6449
# Epoch: 092/100 | Batch 100/469 | Gen/Dis Loss: 0.7933/0.6294
# Epoch: 092/100 | Batch 200/469 | Gen/Dis Loss: 1.0253/0.6198
# Epoch: 092/100 | Batch 300/469 | Gen/Dis Loss: 0.8995/0.6646
# Epoch: 092/100 | Batch 400/469 | Gen/Dis Loss: 0.7896/0.6318
# Time elapsed: 15.22 min
# Epoch: 093/100 | Batch 000/469 | Gen/Dis Loss: 0.7598/0.6466
# Epoch: 093/100 | Batch 100/469 | Gen/Dis Loss: 0.7530/0.6373
# Epoch: 093/100 | Batch 200/469 | Gen/Dis Loss: 0.8703/0.6346
# Epoch: 093/100 | Batch 300/469 | Gen/Dis Loss: 0.7450/0.6482
# Epoch: 093/100 | Batch 400/469 | Gen/Dis Loss: 0.8049/0.6275
# Time elapsed: 15.39 min
# Epoch: 094/100 | Batch 000/469 | Gen/Dis Loss: 0.7697/0.6639
# Epoch: 094/100 | Batch 100/469 | Gen/Dis Loss: 0.8735/0.6353
# Epoch: 094/100 | Batch 200/469 | Gen/Dis Loss: 0.8335/0.6616
# Epoch: 094/100 | Batch 300/469 | Gen/Dis Loss: 0.7018/0.6591
# Epoch: 094/100 | Batch 400/469 | Gen/Dis Loss: 0.8466/0.6760
# Time elapsed: 15.56 min
# Epoch: 095/100 | Batch 000/469 | Gen/Dis Loss: 0.8565/0.6284
# Epoch: 095/100 | Batch 100/469 | Gen/Dis Loss: 0.8967/0.6453
# Epoch: 095/100 | Batch 200/469 | Gen/Dis Loss: 0.7955/0.6743
# Epoch: 095/100 | Batch 300/469 | Gen/Dis Loss: 0.8424/0.6022
# Epoch: 095/100 | Batch 400/469 | Gen/Dis Loss: 0.7978/0.6487
# Time elapsed: 15.72 min
# Epoch: 096/100 | Batch 000/469 | Gen/Dis Loss: 0.7415/0.6442
# Epoch: 096/100 | Batch 100/469 | Gen/Dis Loss: 0.8149/0.6392
# Epoch: 096/100 | Batch 200/469 | Gen/Dis Loss: 0.9326/0.6302
# Epoch: 096/100 | Batch 300/469 | Gen/Dis Loss: 0.8977/0.6385
# Epoch: 096/100 | Batch 400/469 | Gen/Dis Loss: 0.8138/0.6489
# Time elapsed: 15.89 min
# Epoch: 097/100 | Batch 000/469 | Gen/Dis Loss: 0.8903/0.6357
# Epoch: 097/100 | Batch 100/469 | Gen/Dis Loss: 0.8233/0.6458
# Epoch: 097/100 | Batch 200/469 | Gen/Dis Loss: 0.8134/0.6519
# Epoch: 097/100 | Batch 300/469 | Gen/Dis Loss: 0.8932/0.6179
# Epoch: 097/100 | Batch 400/469 | Gen/Dis Loss: 1.0360/0.6498
# Time elapsed: 16.05 min
# Epoch: 098/100 | Batch 000/469 | Gen/Dis Loss: 0.8371/0.6459
# Epoch: 098/100 | Batch 100/469 | Gen/Dis Loss: 0.7883/0.6765
# Epoch: 098/100 | Batch 200/469 | Gen/Dis Loss: 0.8048/0.6555
# Epoch: 098/100 | Batch 300/469 | Gen/Dis Loss: 0.9263/0.6609
# Epoch: 098/100 | Batch 400/469 | Gen/Dis Loss: 0.7522/0.6529
# Time elapsed: 16.22 min
# Epoch: 099/100 | Batch 000/469 | Gen/Dis Loss: 0.7899/0.6334
# Epoch: 099/100 | Batch 100/469 | Gen/Dis Loss: 0.8268/0.6719
# Epoch: 099/100 | Batch 200/469 | Gen/Dis Loss: 0.7912/0.6521
# Epoch: 099/100 | Batch 300/469 | Gen/Dis Loss: 0.7968/0.6328
# Epoch: 099/100 | Batch 400/469 | Gen/Dis Loss: 0.9629/0.6463
# Time elapsed: 16.38 min
# Epoch: 100/100 | Batch 000/469 | Gen/Dis Loss: 0.7389/0.6534
# Epoch: 100/100 | Batch 100/469 | Gen/Dis Loss: 1.0216/0.6466
# Epoch: 100/100 | Batch 200/469 | Gen/Dis Loss: 0.9923/0.6238
# Epoch: 100/100 | Batch 300/469 | Gen/Dis Loss: 0.7489/0.6502
# Epoch: 100/100 | Batch 400/469 | Gen/Dis Loss: 0.7716/0.6363
# Time elapsed: 16.54 min
# Total Training Time: 16.54 min

# %%
import matplotlib.pyplot as plt

model.eval()
# Make new images
z = torch.zeros((5, LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
generated_features = model.generator_forward(z)
imgs = generated_features.view(-1, 28, 28)

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 2.5))

for i, ax in enumerate(axes):
    axes[i].imshow(imgs[i].to(torch.device('cpu')).detach(), cmap='binary')

# %% [markdown]
# ## CNN GANs

# %%
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)
    
class Reshape1(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), 64, 7, 7)

class GAN(torch.nn.Module):

    def __init__(self):
        super(GAN, self).__init__()
        
        
        self.generator = nn.Sequential(
              
            nn.Linear(LATENT_DIM, 3136, bias=False),
            nn.BatchNorm1d(num_features=3136),
            nn.LeakyReLU(inplace=True, negative_slope=0.0001),
            Reshape1(),
            
            nn.ConvTranspose2d(in_channels=64, out_channels=32, kernel_size=(3, 3), stride=(2, 2), padding=1, bias=False),
            nn.BatchNorm2d(num_features=32),
            nn.LeakyReLU(inplace=True, negative_slope=0.0001),
            #nn.Dropout2d(p=0.2),
            
            nn.ConvTranspose2d(in_channels=32, out_channels=16, kernel_size=(3, 3), stride=(2, 2), padding=1, bias=False),
            nn.BatchNorm2d(num_features=16),
            nn.LeakyReLU(inplace=True, negative_slope=0.0001),
            #nn.Dropout2d(p=0.2),
            
            nn.ConvTranspose2d(in_channels=16, out_channels=8, kernel_size=(3, 3), stride=(1, 1), padding=0, bias=False),
            nn.BatchNorm2d(num_features=8),
            nn.LeakyReLU(inplace=True, negative_slope=0.0001),
            #nn.Dropout2d(p=0.2),
            
            nn.ConvTranspose2d(in_channels=8, out_channels=1, kernel_size=(2, 2), stride=(1, 1), padding=0, bias=False),
            nn.Tanh()
        )
        
        self.discriminator = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=8, padding=1, kernel_size=(3, 3), stride=(2, 2), bias=False),
            nn.BatchNorm2d(num_features=8),
            nn.LeakyReLU(inplace=True, negative_slope=0.0001), 
            #nn.Dropout2d(p=0.2),
            
            nn.Conv2d(in_channels=8, out_channels=32, padding=1, kernel_size=(3, 3), stride=(2, 2), bias=False),
            nn.BatchNorm2d(num_features=32),
            nn.LeakyReLU(inplace=True, negative_slope=0.0001), 
            #nn.Dropout2d(p=0.2),
            
            Flatten(),

            nn.Linear(7*7*32, 1),
            #nn.Sigmoid()
        )
         
    def generator_forward(self, z):
        img = self.generator(z)
        return img
    
    def discriminator_forward(self, img):
        pred = model.discriminator(img)
        return pred.view(-1)

# %%
torch.manual_seed(random_seed)

model = GAN()
model = model.to(device)

print(model)
# Out:
# GAN(
#   (generator): Sequential(
#     (0): Linear(in_features=100, out_features=3136, bias=False)
#     (1): BatchNorm1d(3136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.0001, inplace=True)
#     (3): Reshape1()
#     (4): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.0001, inplace=True)
#     (7): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (8): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): LeakyReLU(negative_slope=0.0001, inplace=True)
#     (10): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (11): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): LeakyReLU(negative_slope=0.0001, inplace=True)
#     (13): ConvTranspose2d(8, 1, kernel_size=(2, 2), stride=(1, 1), bias=False)
#     (14): Tanh()
#   )
#   (discriminator): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.0001, inplace=True)
#     (3): Conv2d(8, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.0001, inplace=True)
#     (6): Flatten()
#     (7): Linear(in_features=1568, out_features=1, bias=True)
#   )
# )

# %%
optim_gener = torch.optim.Adam(model.generator.parameters(), lr=generator_learning_rate)
optim_discr = torch.optim.Adam(model.discriminator.parameters(), lr=discriminator_learning_rate)
start_time = time.time()    

discr_costs = []
gener_costs = []
for epoch in range(num_epochs):
    model = model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
    
        # Normalize images to [-1, 1] range
        features = (features - 0.5)*2.
        features = features.view(-1, IMG_SIZE).to(device) 

        targets = targets.to(device)

        valid = torch.ones(targets.size(0)).float().to(device)
        fake = torch.zeros(targets.size(0)).float().to(device)
        

        ### FORWARD AND BACK PROP

        # --------------------------
        # Train Generator
        # --------------------------
        
        # Make new images
        z = torch.zeros((targets.size(0), LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
        generated_features = model.generator_forward(z)
        
        # Loss for fooling the discriminator
        discr_pred = model.discriminator_forward(generated_features.view(targets.size(0), 1, 28, 28))
        
        gener_loss = F.binary_cross_entropy_with_logits(discr_pred, valid)
        
        optim_gener.zero_grad()
        gener_loss.backward()
        optim_gener.step()
        
        # --------------------------
        # Train Discriminator
        # --------------------------        
        
        discr_pred_real = model.discriminator_forward(features.view(targets.size(0), 1, 28, 28))
        real_loss = F.binary_cross_entropy_with_logits(discr_pred_real, valid)
        
        discr_pred_fake = model.discriminator_forward(generated_features.view(targets.size(0), 1, 28, 28).detach())
        fake_loss = F.binary_cross_entropy_with_logits(discr_pred_fake, fake)
        
        discr_loss = 0.5*(real_loss + fake_loss)

        optim_discr.zero_grad()
        discr_loss.backward()
        optim_discr.step()        
        
        discr_costs.append(discr_loss.item())
        gener_costs.append(gener_loss.item())
        
        
        ### LOGGING
        if not batch_idx % 100:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Gen/Dis Loss: %.4f/%.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), gener_loss, discr_loss))

    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
    
print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/100 | Batch 000/469 | Gen/Dis Loss: 0.8375/0.7570
# Epoch: 001/100 | Batch 100/469 | Gen/Dis Loss: 3.5557/0.0325
# Epoch: 001/100 | Batch 200/469 | Gen/Dis Loss: 3.0659/0.0326
# Epoch: 001/100 | Batch 300/469 | Gen/Dis Loss: 2.7739/0.0623
# Epoch: 001/100 | Batch 400/469 | Gen/Dis Loss: 2.0408/0.2393
# Time elapsed: 0.38 min
# Epoch: 002/100 | Batch 000/469 | Gen/Dis Loss: 3.3367/0.0845
# Epoch: 002/100 | Batch 100/469 | Gen/Dis Loss: 2.7151/0.1829
# Epoch: 002/100 | Batch 200/469 | Gen/Dis Loss: 2.2904/0.3147
# Epoch: 002/100 | Batch 300/469 | Gen/Dis Loss: 2.9546/0.1367
# Epoch: 002/100 | Batch 400/469 | Gen/Dis Loss: 1.8786/0.3070
# Time elapsed: 0.75 min
# Epoch: 003/100 | Batch 000/469 | Gen/Dis Loss: 2.6555/0.1398
# Epoch: 003/100 | Batch 100/469 | Gen/Dis Loss: 3.4679/0.5692
# Epoch: 003/100 | Batch 200/469 | Gen/Dis Loss: 2.3066/0.1714
# Epoch: 003/100 | Batch 300/469 | Gen/Dis Loss: 2.5978/0.1601
# Epoch: 003/100 | Batch 400/469 | Gen/Dis Loss: 1.4939/0.5622
# Time elapsed: 1.13 min
# Epoch: 004/100 | Batch 000/469 | Gen/Dis Loss: 1.6006/0.3771
# Epoch: 004/100 | Batch 100/469 | Gen/Dis Loss: 2.3639/0.2197
# Epoch: 004/100 | Batch 200/469 | Gen/Dis Loss: 1.9016/0.4005
# Epoch: 004/100 | Batch 300/469 | Gen/Dis Loss: 0.9748/0.6246
# Epoch: 004/100 | Batch 400/469 | Gen/Dis Loss: 1.8646/0.4430
# Time elapsed: 1.50 min
# Epoch: 005/100 | Batch 000/469 | Gen/Dis Loss: 2.0217/0.2327
# Epoch: 005/100 | Batch 100/469 | Gen/Dis Loss: 1.2410/0.3708
# Epoch: 005/100 | Batch 200/469 | Gen/Dis Loss: 2.3754/0.1659
# Epoch: 005/100 | Batch 300/469 | Gen/Dis Loss: 2.0686/0.2168
# Epoch: 005/100 | Batch 400/469 | Gen/Dis Loss: 3.1221/0.2116
# Time elapsed: 1.86 min
# Epoch: 006/100 | Batch 000/469 | Gen/Dis Loss: 2.2664/0.1746
# Epoch: 006/100 | Batch 100/469 | Gen/Dis Loss: 1.1161/0.5839
# Epoch: 006/100 | Batch 200/469 | Gen/Dis Loss: 1.8497/0.2584
# Epoch: 006/100 | Batch 300/469 | Gen/Dis Loss: 2.3307/0.2486
# Epoch: 006/100 | Batch 400/469 | Gen/Dis Loss: 1.4769/0.4454
# Time elapsed: 2.23 min
# Epoch: 007/100 | Batch 000/469 | Gen/Dis Loss: 1.5846/0.3763
# Epoch: 007/100 | Batch 100/469 | Gen/Dis Loss: 1.3160/0.7253
# Epoch: 007/100 | Batch 200/469 | Gen/Dis Loss
# Epoch: 082/100 | Batch 300/469 | Gen/Dis Loss: 0.6987/0.7431
# Epoch: 082/100 | Batch 400/469 | Gen/Dis Loss: 0.6734/0.6951
# Time elapsed: 29.86 min
# Epoch: 083/100 | Batch 000/469 | Gen/Dis Loss: 0.7530/0.6653
# Epoch: 083/100 | Batch 100/469 | Gen/Dis Loss: 0.7355/0.6636
# Epoch: 083/100 | Batch 200/469 | Gen/Dis Loss: 0.7956/0.6676
# Epoch: 083/100 | Batch 300/469 | Gen/Dis Loss: 0.7732/0.6728
# Epoch: 083/100 | Batch 400/469 | Gen/Dis Loss: 0.7224/0.7030
# Time elapsed: 30.22 min
# Epoch: 084/100 | Batch 000/469 | Gen/Dis Loss: 0.7402/0.6618
# Epoch: 084/100 | Batch 100/469 | Gen/Dis Loss: 0.7282/0.6868
# Epoch: 084/100 | Batch 200/469 | Gen/Dis Loss: 0.7050/0.7351
# Epoch: 084/100 | Batch 300/469 | Gen/Dis Loss: 0.7024/0.7360
# Epoch: 084/100 | Batch 400/469 | Gen/Dis Loss: 0.7391/0.6848
# Time elapsed: 30.58 min
# Epoch: 085/100 | Batch 000/469 | Gen/Dis Loss: 0.7538/0.6597
# Epoch: 085/100 | Batch 100/469 | Gen/Dis Loss: 0.7193/0.6777
# Epoch: 085/100 | Batch 200/469 | Gen/Dis Loss: 0.7150/0.7021
# Epoch: 085/100 | Batch 300/469 | Gen/Dis Loss: 0.7303/0.6675
# Epoch: 085/100 | Batch 400/469 | Gen/Dis Loss: 0.6854/0.6991
# Time elapsed: 30.94 min
# Epoch: 086/100 | Batch 000/469 | Gen/Dis Loss: 0.7442/0.6737
# Epoch: 086/100 | Batch 100/469 | Gen/Dis Loss: 0.7544/0.6752
# Epoch: 086/100 | Batch 200/469 | Gen/Dis Loss: 0.7447/0.6955
# Epoch: 086/100 | Batch 300/469 | Gen/Dis Loss: 0.7210/0.6956
# Epoch: 086/100 | Batch 400/469 | Gen/Dis Loss: 0.7429/0.6914
# Time elapsed: 31.30 min
# Epoch: 087/100 | Batch 000/469 | Gen/Dis Loss: 0.7488/0.6984
# Epoch: 087/100 | Batch 100/469 | Gen/Dis Loss: 0.7395/0.6979
# Epoch: 087/100 | Batch 200/469 | Gen/Dis Loss: 0.7544/0.6775
# Epoch: 087/100 | Batch 300/469 | Gen/Dis Loss: 0.7637/0.6801
# Epoch: 087/100 | Batch 400/469 | Gen/Dis Loss: 0.7221/0.6735
# Time elapsed: 31.66 min
# Epoch: 088/100 | Batch 000/469 | Gen/Dis Loss: 0.7457/0.6676
# Epoch: 088/100 | Batch 100/469 | Gen/Dis Loss: 0.7624/0.6699
# Epoch: 088/100 | Batch 200/469 | Gen/Dis Loss: 0.7516/0.6708
# Epoch: 088/100 | Batch 300/469 | Gen/Dis Loss: 0.7046/0.6972
# Epoch: 088/100 | Batch 400/469 | Gen/Dis Loss: 0.7577/0.6922
# Time elapsed: 32.02 min
# Epoch: 089/100 | Batch 000/469 | Gen/Dis Loss: 0.7790/0.6597
# Epoch: 089/100 | Batch 100/469 | Gen/Dis Loss: 0.7201/0.7063
# Epoch: 089/100 | Batch 200/469 | Gen/Dis Loss: 0.6720/0.7106
# Epoch: 089/100 | Batch 300/469 | Gen/Dis Loss: 0.7238/0.6709
# Epoch: 089/100 | Batch 400/469 | Gen/Dis Loss: 0.7651/0.6770
# Time elapsed: 32.38 min
# Epoch: 090/100 | Batch 000/469 | Gen/Dis Loss: 0.7770/0.6960
# Epoch: 090/100 | Batch 100/469 | Gen/Dis Loss: 0.7145/0.6936
# Epoch: 090/100 | Batch 200/469 | Gen/Dis Loss: 0.7337/0.6353
# Epoch: 090/100 | Batch 300/469 | Gen/Dis Loss: 0.7135/0.7139
# Epoch: 090/100 | Batch 400/469 | Gen/Dis Loss: 0.7455/0.6761
# Time elapsed: 32.74 min
# Epoch: 091/100 | Batch 000/469 | Gen/Dis Loss: 0.7256/0.6768
# Epoch: 091/100 | Batch 100/469 | Gen/Dis Loss: 0.6660/0.7324
# Epoch: 091/100 | Batch 200/469 | Gen/Dis Loss: 0.7477/0.6584
# Epoch: 091/100 | Batch 300/469 | Gen/Dis Loss: 0.7228/0.6546
# Epoch: 091/100 | Batch 400/469 | Gen/Dis Loss: 0.7227/0.6829
# Time elapsed: 33.10 min
# Epoch: 092/100 | Batch 000/469 | Gen/Dis Loss: 0.7106/0.6965
# Epoch: 092/100 | Batch 100/469 | Gen/Dis Loss: 0.7035/0.6839
# Epoch: 092/100 | Batch 200/469 | Gen/Dis Loss: 0.7346/0.6711
# Epoch: 092/100 | Batch 300/469 | Gen/Dis Loss: 0.7951/0.6458
# Epoch: 092/100 | Batch 400/469 | Gen/Dis Loss: 0.7523/0.6625
# Time elapsed: 33.46 min
# Epoch: 093/100 | Batch 000/469 | Gen/Dis Loss: 0.7444/0.7448
# Epoch: 093/100 | Batch 100/469 | Gen/Dis Loss: 0.7941/0.6827
# Epoch: 093/100 | Batch 200/469 | Gen/Dis Loss: 0.7781/0.6678
# Epoch: 093/100 | Batch 300/469 | Gen/Dis Loss: 0.7312/0.6952
# Epoch: 093/100 | Batch 400/469 | Gen/Dis Loss: 0.7343/0.6639
# Time elapsed: 33.82 min
# Epoch: 094/100 | Batch 000/469 | Gen/Dis Loss: 0.6472/0.7051
# Epoch: 094/100 | Batch 100/469 | Gen/Dis Loss: 0.7386/0.6877
# Epoch: 094/100 | Batch 200/469 | Gen/Dis Loss: 0.7336/0.6904
# Epoch: 094/100 | Batch 300/469 | Gen/Dis Loss: 0.7360/0.6766
# Epoch: 094/100 | Batch 400/469 | Gen/Dis Loss: 0.7092/0.6855
# Time elapsed: 34.18 min
# Epoch: 095/100 | Batch 000/469 | Gen/Dis Loss: 0.6855/0.6659
# Epoch: 095/100 | Batch 100/469 | Gen/Dis Loss: 0.7352/0.6931
# Epoch: 095/100 | Batch 200/469 | Gen/Dis Loss: 0.7022/0.6966
# Epoch: 095/100 | Batch 300/469 | Gen/Dis Loss: 0.7097/0.6929
# Epoch: 095/100 | Batch 400/469 | Gen/Dis Loss: 0.7205/0.6809
# Time elapsed: 34.54 min
# Epoch: 096/100 | Batch 000/469 | Gen/Dis Loss: 0.6971/0.6838
# Epoch: 096/100 | Batch 100/469 | Gen/Dis Loss: 0.6870/0.6956
# Epoch: 096/100 | Batch 200/469 | Gen/Dis Loss: 0.7392/0.7043
# Epoch: 096/100 | Batch 300/469 | Gen/Dis Loss: 0.7111/0.6776
# Epoch: 096/100 | Batch 400/469 | Gen/Dis Loss: 0.7024/0.6740
# Time elapsed: 34.90 min
# Epoch: 097/100 | Batch 000/469 | Gen/Dis Loss: 0.7098/0.6834
# Epoch: 097/100 | Batch 100/469 | Gen/Dis Loss: 0.7277/0.6964
# Epoch: 097/100 | Batch 200/469 | Gen/Dis Loss: 0.7455/0.6846
# Epoch: 097/100 | Batch 300/469 | Gen/Dis Loss: 0.7494/0.6832
# Epoch: 097/100 | Batch 400/469 | Gen/Dis Loss: 0.7027/0.6812
# Time elapsed: 35.26 min
# Epoch: 098/100 | Batch 000/469 | Gen/Dis Loss: 0.6874/0.6797
# Epoch: 098/100 | Batch 100/469 | Gen/Dis Loss: 0.6860/0.7174
# Epoch: 098/100 | Batch 200/469 | Gen/Dis Loss: 0.6983/0.7164
# Epoch: 098/100 | Batch 300/469 | Gen/Dis Loss: 0.7140/0.6935
# Epoch: 098/100 | Batch 400/469 | Gen/Dis Loss: 0.7495/0.6635
# Time elapsed: 35.62 min
# Epoch: 099/100 | Batch 000/469 | Gen/Dis Loss: 0.7168/0.6971
# Epoch: 099/100 | Batch 100/469 | Gen/Dis Loss: 0.7077/0.7001
# Epoch: 099/100 | Batch 200/469 | Gen/Dis Loss: 0.7057/0.6953
# Epoch: 099/100 | Batch 300/469 | Gen/Dis Loss: 0.7579/0.6344
# Epoch: 099/100 | Batch 400/469 | Gen/Dis Loss: 0.6931/0.6905
# Time elapsed: 35.98 min
# Epoch: 100/100 | Batch 000/469 | Gen/Dis Loss: 0.7429/0.6829
# Epoch: 100/100 | Batch 100/469 | Gen/Dis Loss: 0.7372/0.6624
# Epoch: 100/100 | Batch 200/469 | Gen/Dis Loss: 0.7691/0.6269
# Epoch: 100/100 | Batch 300/469 | Gen/Dis Loss: 0.7588/0.6557
# Epoch: 100/100 | Batch 400/469 | Gen/Dis Loss: 0.7220/0.7073
# Time elapsed: 36.34 min
# Total Training Time: 36.34 min

# %%
model.eval()
# Make new images
z = torch.zeros((5, LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
generated_features = model.generator_forward(z)
imgs = generated_features.view(-1, 28, 28)

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 2.5))

for i, ax in enumerate(axes):
    axes[i].imshow(imgs[i].to(torch.device('cpu')).detach(), cmap='binary')
